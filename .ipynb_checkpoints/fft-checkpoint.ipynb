# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import log10 as lg
import numpy as np
import matplotlib.pyplot as plt
import math
import matplotlib
from scipy.fftpack import fft,ifft

matplotlib.rcParams['xtick.labelsize'] = 25
matplotlib.rcParams['ytick.labelsize'] = 25
matplotlib.rcParams['xtick.direction'] = 'in'
matplotlib.rcParams['ytick.direction'] = 'in'
matplotlib.rcParams['xtick.major.size'] = 8
matplotlib.rcParams['ytick.major.size'] = 8
matplotlib.rcParams['xtick.minor.size'] = 4
matplotlib.rcParams['ytick.minor.size'] = 4
matplotlib.rcParams['xtick.top'] = True
matplotlib.rcParams['ytick.right'] = True
matplotlib.rcParams['axes.labelpad'] = 8.0
matplotlib.rcParams['figure.constrained_layout.h_pad'] = 0
plt.rcParams['text.usetex'] = True
plt.rc('text', usetex=True)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.rcParams['font.sans-serif'] = ['Times New Roman']

from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
data2 = np.genfromtxt('data/kip.dat')

t2=data2[:,0]
hp2=data2[:,1]


hp=np.nan_to_num(hp2)
fft_hp = fft(hp)
n2=len(t2)
T=t2[-1]/(n2-1)
xf2= np.linspace(0.0, 1.0/(2.0*T), n2//2)
ps2 = 2.0/n2 * np.abs(fft_hp[0:n2//2])

fig, ax2 = plt.subplots(1, figsize=(12,8))
matplotlib.rcParams['xtick.labelsize'] = 30
matplotlib.rcParams['ytick.labelsize'] = 30
plt.subplots_adjust(hspace=0.0)


ax2.semilogx(xf2, ps2, linewidth=1.5,color='k')
ax2.set_xlabel(r'${f}$',fontsize=25)
ax2.set_ylabel(r'$\mathcal{F}$',fontsize=30)
# ax2.set_ylim(1*1e-30,7*1e-23)
# ax2.set_yticks([1e-29,1e-27,1e-25,1e-23])
ax2.grid()
plt.xlim(0.001,1)
plt.ylim(-0.01,0.4)
# plt.axvline(x=101.849)
# plt.axvline(x=100.374)
# plt.axvline(x=98.8987)
plt.minorticks_on()
plt.savefig("fft.pdf", format='pdf', bbox_inches="tight")

# %%
data2 = np.genfromtxt('data/kip.dat')

t2=data2[:,0]
hp2=data2[:,1]


hp=np.nan_to_num(hp2)
fft_hp = fft(hp)
n2=len(t2)
T=t2[-1]/(n2-1)
xf2= np.linspace(0.0, 1.0/(2.0*T), n2//2)
ps2 = 2.0/n2 * np.abs(fft_hp[0:n2//2])

# %%
fig, ax2 = plt.subplots(1, figsize=(12,8))
matplotlib.rcParams['xtick.labelsize'] = 30
matplotlib.rcParams['ytick.labelsize'] = 30
plt.subplots_adjust(hspace=0.0)


ax2.semilogx(xf2, ps2, linewidth=1.5,color='k')
ax2.set_xlabel(r'${f}$',fontsize=25)
ax2.set_ylabel(r'$\mathcal{F}$',fontsize=30)
# ax2.set_ylim(1*1e-30,7*1e-23)
# ax2.set_yticks([1e-29,1e-27,1e-25,1e-23])
ax2.grid()
plt.xlim(0.001,1)
plt.ylim(-0.01,0.4)
# plt.axvline(x=101.849)
# plt.axvline(x=100.374)
# plt.axvline(x=98.8987)
plt.minorticks_on()
plt.savefig("fft.pdf", format='pdf', bbox_inches="tight")

# %%
fig, ax2 = plt.subplots(1, figsize=(12,8))
matplotlib.rcParams['xtick.labelsize'] = 30
matplotlib.rcParams['ytick.labelsize'] = 30
plt.subplots_adjust(hspace=0.0)


ax2.loglog(xf2, ps2, linewidth=1.5,color='k')
ax2.set_xlabel(r'${f}$',fontsize=25)
ax2.set_ylabel(r'$\mathcal{F}$',fontsize=30)
# ax2.set_ylim(1*1e-30,7*1e-23)
# ax2.set_yticks([1e-29,1e-27,1e-25,1e-23])
ax2.grid()
plt.xlim(0.001,1)
plt.ylim(-0.01,0.4)
# plt.axvline(x=101.849)
# plt.axvline(x=100.374)
# plt.axvline(x=98.8987)
plt.minorticks_on()
plt.savefig("fft.pdf", format='pdf', bbox_inches="tight")
# Out:
# <ipython-input-8-5006a1993637>:14: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(-0.01,0.4)
